# %%
from notebook_utils import setup
import pandas as pd
import networkx as nx
from collections import defaultdict
import time
import networkit

setup()

import matplotlib.style as style
# Out:
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %%
DATE = "16-dec"
DATA_DIR = "../data/{}/".format(DATE)
EXPORT_DIR = "../data/dataframes/{}/".format(DATE)

# %%
import pickle 
with open("./cached_graph.pickle", "rb") as f:
    cached_graph = pickle.load(f)

# %%
cached_graph.keys()
# Out:
# dict_keys(['all_user_clusters', 'graph', 'node_id_map', 'clustering_directed_unweighted', 'clustering_directed_weighted', 'clustering_undirected_unweighted'])

# %%
node_id_map = cached_graph["node_id_map"]

# %%
cached_graph["graph"].nodes[node_id_map["240454812"]]
# Out:
# {'user_id': '240454812', 'label': 'GenFlynn', 'followers': 950567}

# %%
print("Total nodes in graph:", len(cached_graph["graph"].nodes))
print("Clustered users:", len(cached_graph["clustering_directed_unweighted"][0]))
# Out:
# Total nodes in graph: 1887736
# Clustered users: 1885600

# %%
node_community_map = cached_graph["clustering_directed_weighted"][0]

def get_graph_with_communities(G, node_community_map):
    nodes_to_keep = []
    '''Add community to node attributes'''
    for n, c in node_community_map.items():
        if (c < 5):
            G.nodes[n]['community'] = c
            nodes_to_keep.append(n)
    return G.subgraph(nodes_to_keep)

graph_with_communities = get_graph_with_communities(cached_graph["graph"], node_community_map).copy
print(len(graph_with_communities.nodes))
print(graph_with_communities.nodes[0])
# Out:
# 1697944
# {'user_id': '1097618307778150400', 'label': 'PacificReports', 'followers': 10043, 'community': 2}

# %%
import pickle 
with open("./graph_with_communities.pickle", "wb") as f:
    pickle.dump(graph_with_communities.copy(), f)

# %%
import pickle 
with open("./graph_with_communities.pickle", "rb") as f:
    graph_with_communities = pickle.load(f)

# %%
def get_largest_subgraph(graph):
    undirected_graph = graph.to_undirected()
    connected_components = [graph.subgraph(c) for c in nx.connected_components(undirected_graph)]
    largest_component = max(connected_components, key=len)
    return graph.subgraph(largest_component.nodes)

# %%
nx_to_nk = {}

def to_networkit_graph(nx_graph):
    id_map = dict((idx, node) for (idx, node) in enumerate(nx_graph.nodes()))

    if (nx_graph not in nx_to_nk):
        nx_to_nk[nx_graph] = networkit.nxadapter.nx2nk(nx_graph, weightAttr="weight")

    return nx_to_nk[nx_graph], id_map

# %%
def split_community_graphs (G):
    l_nodes = []
    r_nodes = []

    for n, data in G.nodes(data=True):
        if (data["community"] == 0):
            l_nodes.append(n)
        else:
            r_nodes.append(n)
    return G.subgraph(l_nodes), G.subgraph(r_nodes)

l_graph, r_graph = split_community_graphs(graph_with_communities)

# %%
print("Left graph")
print("Nodes: {}, edges: {}".format(len(l_graph.nodes), len(l_graph.edges)))
print("Right graph")
print("Nodes: {}, edges: {}".format(len(r_graph.nodes), len(r_graph.edges)))
# Out:
# Left graph
# Nodes: 860976, edges: 3247717
# Right graph
# Nodes: 836968, edges: 11342929

# %%
def top_closeness(nx_graph, k=15):
    nk_graph, id_map = to_networkit_graph(nx_graph)

    start = time.time()
    top_closeness = networkit.centrality.TopCloseness(nk_graph, k, True, True)
    top_closeness.run()
    end = time.time()


    top_scores_by_node_id = {}
    for idx, score in zip(top_closeness.topkNodesList(), top_closeness.topkScoresList()):
        top_scores_by_node_id[id_map[idx]] = score
    print("Time elapsed: {}s".format(end - start))
    return top_scores_by_node_id

# %%
l_closeness = top_closeness(l_graph, 10000)
l_closeness
# Out:
# Time elapsed: 572.6662971973419s
# {119: 0.18513846984211368,
#  204: 0.17855526132884464,
#  271: 0.17735512015740376,
#  284: 0.1768810406179521,
#  449: 0.17315885302412262,
#  1626: 0.17294491445814608,
#  2146: 0.17221641804619442,
#  263: 0.17096122428456217,
#  431: 0.16922017598390288,
#  201: 0.16726690365648858,
#  2397: 0.1671504173427108,
#  319: 0.16657699655790767,
#  1811: 0.16470459149670305,
#  356: 0.16418341423327304,
#  3046: 0.1637922081248099,
#  340: 0.16293364842475336,
#  250: 0.1629217287035964,
#  172: 0.16259234214481713,
#  294: 0.16224374020989257,
#  2298: 0.16200465652431606,
#  2333: 0.16188764824036156,
#  437: 0.16154742813322914,
#  287: 0.16022205083991742,
#  799: 0.16004895235635697,
#  1615: 0.1599876526582014,
#  2021: 0.15980511579931334,
#  167: 0.1596560175270101,
#  2734: 0.15925934506481776,
#  3787: 0.15811690232281034,
#  634: 0.1580303475907022,
#  351: 0.1577513741338133,
#  2266: 0.15722078638578585,
#  260: 0.156891984327749,
#  288: 0.15649500654094944,
#  3931: 0.1560967501773229,
#  544: 0.15604526548274592,
#  3039: 0.15549047211384104,
#  4376: 0.1553099826612632,
#  2010: 0.15472431799936326,
#  2149: 0.15418900222119247,
#  3641: 0.15418252101654856,
#  1668: 0.1541351866245015,
#  3041: 0.1538682657813541,
#  385: 0.15359748187905312,
#  2723: 0.15356973511990682,
#  1807: 0.15277973668832012,
#  3049: 0.15273228691544236,
#  630: 0.1523409431261593,
#  2735: 0.15233509669636794,
#  624: 0.15213310471982072,
#  1649: 0.15212674722359765,
#  2737: 0.15154847568644372,
#  5242: 0.1514852988875695,
#  184: 0.15131627683378343,
#  3053: 0.15105068830689405,
#  9636: 0.15083598090566122,
#  5791: 0.1507108642682228,
#  241: 0.15062021893400931,
#  1608: 0.15023200902571576,
#  386: 0.15022523270088395,
#  66: 0.15018323460796937,
#  4069: 0.1501548770264114,
#  460: 0.14981267444638943,
#  643: 0.14965563455889191,
#  1659: 0.1495664692851168,
#  5577: 0.14922963777541973,
#  429: 0.1490104669773355,
#  793: 0.1488867950874288,
#  334: 0.1486382945832311,
#  4206: 0.1486151265189118,
#  3991: 0.14835920055284696,
#  739: 0.14834787159781643,
#  3979: 0.14832941521790563,
#  2739: 0.14830796589364081,
#  543: 0.14796071383069684,
#  541: 0.1478559436216254,
#  1647: 0.1477182212038379,
#  369: 0.14765407113907866,
#  2088: 0.14765222768369166,
#  357: 0.14760087657091744,
#  2002: 0.14757893886368673,
#  189: 0.14743929142478845,
#  1725: 0.14727576389369706,
    }, f)

# %%
import pickle 
with open("./closeness.pickle", "rb") as f:
    closeness = pickle.load(f)

# %%
df_users_with_clustering = pd.read_pickle("./df_users_with_clustering.pickle")
df_users_with_clustering.head()
# Out:
#                      protected friends            created_at  \
# datastore_id
# 1334881524664193027      False    None  2020-12-04T15:25:47Z
# 1334881805024043010      False    None  2020-12-04T15:28:30Z
# 1334882729859682310      False    None  2020-12-04T15:30:26Z
# 1334883015265226752      False    None  2020-12-04T15:32:10Z
# 1334883045988474886      False    None  2020-12-04T15:31:56Z
#
#                                                       name  friends_count  \
# datastore_id
# 1334881524664193027                          venton talley              8
# 1334881805024043010                    🇺🇸Freedom Fighter🇺🇸           1028
# 1334882729859682310  Hypocritical Liberal Wannabe TB Aidan              0
# 1334883015265226752                        Conversing Post            128
# 1334883045988474886                         Ajmira sultana             62
#
#                      verified  followers_count      location  followed_cnts  \
# datastore_id
# 1334881524664193027     False                3          None              0
# 1334881805024043010     False               41  MAGA Country              0
# 1334882729859682310     False                2          None              0
# 1334883015265226752     False                2          None              0
# 1334883045988474886     False               17          None              0
#
#                              handle   url  clustering_directed_unweighted  \
# datastore_id
# 1334881524664193027    TalleyVenton  None                              -1
# 1334881805024043010    RiSeAgAiN888  None                           35043
# 1334882729859682310       LiberalTb  None                              -1
# 1334883015265226752  ConversingPost  None                              -1
# 1334883045988474886   SultanaAjmira  None                              -1
#
#                      clustering_directed_weighted  \
# datastore_id
# 1334881524664193027                            -1
# 1334881805024043010                             2
# 1334882729859682310                            -1
# 1334883015265226752                            -1
# 1334883045988474886                            -1
#
#                      clustering_undirected_unweighted
# datastore_id
# 1334881524664193027                                -1
# 1334881805024043010                                 0
# 1334882729859682310                                -1
# 1334883015265226752                                -1
# 1334883045988474886                                -1

# %%
for n, score in r_closeness.items():
    print(graph_with_communities.nodes[n])
# Out:
# {'user_id': '25073877', 'label': 'realDonaldTrump', 'followers': 87364085, 'community': 1}
# {'user_id': '187680645', 'label': 'LLinWood', 'followers': 216826, 'community': 1}
# {'user_id': '770781940341288960', 'label': 'RudyGiuliani', 'followers': 849467, 'community': 1}
# {'user_id': '26487169', 'label': 'LouDobbs', 'followers': 2263546, 'community': 1}
# {'user_id': '4041824789', 'label': 'RSBNetwork', 'followers': 181041, 'community': 1}
# {'user_id': '240454812', 'label': 'GenFlynn', 'followers': 950567, 'community': 1}
# {'user_id': '586707638', 'label': 'SidneyPowell1', 'followers': 482623, 'community': 1}
# {'user_id': '2853461537', 'label': 'ScottAdamsSays', 'followers': 596514, 'community': 1}
# {'user_id': '16989178', 'label': 'JamesOKeefeIII', 'followers': 787461, 'community': 1}
# {'user_id': '18266688', 'label': 'TomFitton', 'followers': 1210705, 'community': 1}

# %%
for n, score in l_closeness.items():
    print(graph_with_communities.nodes[n])
# Out:
# {'user_id': '15952856', 'label': 'AriBerman', 'followers': 160928, 'community': 0}
# {'user_id': '3622368202', 'label': 'JohnFetterman', 'followers': 73038, 'community': 0}
# {'user_id': '14529929', 'label': 'jaketapper', 'followers': 2793144, 'community': 0}
# {'user_id': '32871086', 'label': 'kylegriffin1', 'followers': 933613, 'community': 0}
# {'user_id': '233842454', 'label': 'justinamash', 'followers': 462845, 'community': 0}
# {'user_id': '184860130', 'label': 'TimAlberta', 'followers': 103413, 'community': 0}
# {'user_id': '39155029', 'label': 'mkraju', 'followers': 462443, 'community': 0}
# {'user_id': '20118080', 'label': 'BrendanKeefe', 'followers': 5449, 'community': 0}
# {'user_id': '32551884', 'label': 'alanfeuer', 'followers': 22760, 'community': 0}
# {'user_id': '22129280', 'label': 'jimsciutto', 'followers': 426186, 'community': 0}
# {'user_id': '16563015', 'label': 'bluestein', 'followers': 62521, 'community': 0}
# {'user_id': '807095', 'label': 'nytimes', 'followers': 47663855, 'community': 0}
# {'user_id': '17436250', 'label': 'nytmike', 'followers': 227336, 'community': 0}
# {'user_id': '14362404', 'label': 'bradheath', 'followers': 69846, 'community': 0}
# {'user_id': '426802833', 'label': 'AP_Politics', 'followers': 553889, 'community': 0}
# {'user_id': '7768402', 'label': 'ryanjreilly', 'followers': 115354, 'community': 0}
# {'user_id': '60506242', 'label': 'KlasfeldReports', 'followers': 180005, 'community': 0}
# {'user_id': '137752344', 'label': 'EllenLWeintraub', 'followers': 75534, 'community': 0}
# {'user_id': '363708415', 'label': 'C_C_Krebs', 'followers': 76653, 'community': 0}
# {'user_id': '274294204', 'label': 'willsommer', 'followers': 113872, 'community': 0}
# {'user_id': '27075032', 'label': 'oliverdarcy', 'followers': 149544, 'community': 0}
# {'user_id': '39030654', 'label': 'ewong', 'followers': 130628, 'community': 0}
# {'user_id': '49031364', 'label': 'MarshallCohen', 'followers': 69405, 'community': 0}
# {'user_id': '18812572', 'label': '60Minutes', 'followers': 1127431, 'community': 0}
# {'user_id': '225265639', 'label': 'ddale8', 'followers': 1144173, 'community': 0}
# {'user_id': '47034524', 'label': 'rickhasen', 'followers': 55381, 'community': 0}
# {'user_id': '180107694', 'label': 'kaitlancollins', 'followers': 676220, 'community': 0}
# {'user_id': '15751676', 'label': 'MattNegrin', 'followers': 44839, 'community': 0}
# {'user_id': '88223320', 'label': 'grace_panetta', 'followers': 24666, 'community': 0}
# {'user_id': '54885334', 'label': 'cliffordlevy', 'followers': 33376, 'community': 0}
# {'user_id': '136300373', 'label': 'AaronBlake', 'followers': 144469, 'community': 0}
# {'user_id': '61734492', 'label': 'Fahrenthold', 'followers': 821865, 'community': 0}
# {'user_id': '242907470', 'label': 'gregpmiller', 'followers': 126932, 'community': 0}
# {'user_id': '23281108', 'label': 'marceelias', 'followers': 177668, 'community': 0}
# {'user_id': '84653850', 'label': 'BrendanNyhan', 'followers': 83501, 'community': 0}
# {'user_id': '255347566', 'label': 'jimrutenberg', 'followers': 34823, 'community': 0}
# {'user_id': '93069110', 'label': 'maggieNYT', 'followers': 1541009, 'community': 0}
# {'user_id': '14834340', 'label': 'jayrosen_nyu', 'followers': 294604, 'community': 0}
# {'user_id': '21431618', 'label': 'mckaycoppins', 'followers': 151647, 'community': 0}
# {'user_id': '235196204', 'label': 'GlennKesslerWP', 'followers': 137434, 'community': 0}
# {'user_id': '240107748', 'label': 'DavidAFrench', 'followers': 233730, 'community': 0}
# {'user_id': '130557513', 'label': 'mehdirhasan', 'followers': 971203, 'community': 0}
# {'user_id': '14515799', 'label': 'brianstelter', 'followers': 751928, 'community': 0}
# {'user_id': '415581517', 'label': 'MikeBalsamo1', 'followers': 15823, 'community': 0}
# {'user_id': '259395895', 'label': 'JohnJHarwood', 'followers': 415209, 'community': 0}
# {'user_id': '60876782', 'label': 'GabrielSterling', 'followers': 27026, 'community': 0}
# {'user_id': '102594136', 'label': 'oneunderscore__', 'followers': 140001, 'community': 0}
# {'user_id': '640893', 'label': 'EWErickson', 'followers': 212938, 'community': 0}
# {'user_id': '1176994477', 'label': 'TheLeadCNN', 'followers': 209781, 'community': 0}
# {'user_id': '561516853', 'label': 'JaneMayerNYer', 'followers': 251489, 'community': 0}
# {'user_id': '1017500185356853248', 'label': 'SenBillCassidy', 'followers': 29253, 'community': 0}
# {'user_id': '375662595', 'label': 'EricLiptonNYT', 'followers': 177553, 'community': 0}
# {'user_id': '115564212', 'label': 'IsaacDovere', 'followers': 70316, 'community': 0}
# {'user_id': '302312898', 'label': 'Ike_Saul', 'followers': 12945, 'community': 0}
# {'user_id': '2400284491', 'label': 'RevDrBarber', 'followers': 305953, 'community': 0}
# {'user_id': '18617717', 'label': 'benfritz', 'followers': 13653, 'community': 0}
# {'user_id': '282545479', 'label': 'mikiebarb', 'followers': 262249, 'community': 0}
# {'user_id': '19203768', 'label': 'katestarbird', 'followers': 31277, 'community': 0}
# {'user_id': '21268897', 'label': 'joshtpm', 'followers': 340825, 'community': 0}
# {'user_id': '51241574', 'label': 'AP', 'followers': 14507714, 'community': 0}
# {'user_id': '28785486', 'label': 'ABC', 'followers': 16013155, 'community': 0}
# {'user_id': '407396556', 'label': 'JDiamond1', 'followers': 184496, 'community': 0}
# {'user_id': '143500773', 'label': 'justinbaragona', 'followers': 20603, 'community': 0}
# {'user_id': '16326882', 'label': 'AdamSerwer', 'followers': 316981, 'community': 0}
# {'user_id': '407464670', 'label': 'APFactCheck', 'followers': 40853, 'community': 0}
# {'user_id': '11744152', 'label': 'yashar', 'followers': 697075, 'community': 0}
# {'user_id': '950531', 'label': 'pbump', 'followers': 143559, 'community': 0}
# {'user_id': '326560315', 'label': 'SollenbergerRC', 'followers': 14051, 'community': 0}
# {'user_id': '438843965', 'label': 'stphnfwlr', 'followers': 14150, 'community': 0}
# {'user_id': '64916983', 'label': 'joshgerstein', 'followers': 69373, 'community': 0}
# {'user_id': '39245720', 'label': 'tripgabriel', 'followers': 33620, 'community': 0}
# {'user_id': '304679484', 'label': 'HamillHimself', 'followers': 4015075, 'community': 0}
# {'user_id': '273700859', 'label': 'kpolantz', 'followers': 41681, 'community': 0}
# {'user_id': '69773058', 'label': 'stephenfhayes', 'followers': 314597, 'community': 0}
# {'user_id': '88215673', 'label': 'mjs_DC', 'followers': 66685, 'community': 0}
# {'user_id': '780206406024691712', 'label': 'neal_katyal', 'followers': 569479, 'community': 0}
# {'user_id': '926601', 'label': 'vermontgmg', 'followers': 85048, 'community': 0}
# {'user_id': '471677441', 'label': 'gtconway3d', 'followers': 1599048, 'community': 0}
# {'user_id': '964234828039249920', 'label': 'CISAKrebs', 'followers': 15004, 'community': 0}
# {'user_id': '218325695', 'label': 'Bencjacobs', 'followers': 192204, 'community': 0}
# {'user_id': '459872442', 'label': 'RadioFreeTom', 'followers': 475017, 'community': 0}
# {'user_id': '548384458', 'label': 'JoyceWhiteVance', 'followers': 665654, 'community': 0}
# {'user_id': '1171109054', 'label': 'rgoodlaw', 'followers': 123811, 'community': 0}
# {'user_id': '31565351', 'label': 'AnaCabrera', 'followers': 119960, 'community': 0}
# {'user_id': '705706292', 'label': 'rebeccaballhaus', 'followers': 101589, 'community': 0}
# {'user_id': '182398325', 'label': 'JonLemire', 'followers': 200655, 'community': 0}
# {'user_id': '29077161', 'label': 'JustinGrayWSB', 'followers': 8775, 'community': 0}
# {'user_id': '813311743', 'label': 'NumbersMuncher', 'followers': 61149, 'community': 0}
# {'user_id': '14413466', 'label': 'RalstonReports', 'followers': 106060, 'community': 0}
# {'user_id': '19847765', 'label': 'sahilkapur', 'followers': 164249, 'community': 0}
# {'user_id': '1399966783', 'label': 'TomBossert', 'followers': 31764, 'community': 0}
# {'user_id': '325001316', 'label': 'KenDilanianNBC', 'followers': 188934, 'community': 0}
# {'user_id': '15464697', 'label': 'JuddLegum', 'followers': 450144, 'community': 0}
# {'user_id': '571297251', 'label': 'IChotiner', 'followers': 81977, 'community': 0}
# {'user_id': '15742985', 'label': 'lachlan', 'followers': 92920, 'community': 0}
# {'user_id': '3060489838', 'label': 'KevinMKruse', 'followers': 442398, 'community': 0}
# {'user_id': '14298769', 'label': 'MollyJongFast', 'followers': 749336, 'community': 0}
# {'user_id': '327862439', 'label': 'jonathanvswan', 'followers': 609976, 'community': 0}
# {'user_id': '4207961', 'label': 'chrislhayes', 'followers': 2272061, 'community': 0}
# {'user_id': '255812611', 'label': 'donwinslow', 'followers': 506008, 'community': 0}

# %%
fast_graphs = [networkit.nxadapter.nx2nk(g, weightAttr="weight") for g in community_subgraphs]

# %%
community_subgraphs[4].nodes()[2336]
# Out:
# {'user_id': '98294131', 'label': '1VAFI', 'followers': 2240, 'community': 4}

# %%
centralities = nx.algorithms.centrality.closeness_centrality(community_subgraphs[4].reverse(), wf_improved=True)

# %%
max_cent = 0
for n, c in centralities.items():
    if (c > max_cent):
        max_cent = c
max_cent
# Out:
# 0.1650349316983805

# %%
centralities[id_map[460]]
# Out:
# 0.1650349316983805

# %%
len(community_subgraphs[4].nodes)
# Out:
# 23414

# %%
start = time.time()
Closeness = networkit.centrality.Closeness(fast_graphs[2], True, 1)
Closeness.run()
# Closeness.ranking()[:10]
end = time.time()
print("Time taken", end - start)

# %%
community_graphs[1].nodes[node_id_map["25073877"]]
# Out:
# {'user_id': '25073877',
#  'label': 'realDonaldTrump',
#  'followers': 87364085,
#  'community': 1}

# %%
def time_func(func):
    def timed(*args):
        start = time.time()
        ret = func(*args)
        end = time.time()
        print("Time taken", end - start)
        return ret
    return timed

# %%
timed_centrality = time_func(nx.algorithms.centrality.closeness_centrality)

# %%
timed_centrality(community_graphs[4], 1014567)
# Out:
# Time taken 0.5843698978424072
# 0.0002485021918669892

# %%
print("Nodes:", len(community_graphs[4].nodes))
print("Edges", len(community_graphs[4].edges))
print("Normal")
commmunity_graphs_4_closeness = timed_centrality(community_graphs[4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-845519dea1cc> in <module>
# ----> 1 print("Nodes:", len(community_graphs[4].nodes))
#       2 print("Edges", len(community_graphs[4].edges))
#       3 print("Normal")
#       4 commmunity_graphs_4_closeness = timed_centrality(community_graphs[4])
#
# NameError: name 'community_graphs' is not defined

# %%
print(len(community_graphs[4].nodes), len(community_graphs[4].edges))
# Out:
# 23414 47261

# %%
commmunity_graphs_3_closeness = timed_centrality(community_graphs[3])
# Out:
# Time taken 12.953757762908936

# %%
print(len(community_graphs[3].nodes), len(community_graphs[3].edges))
# Out:
# 33587 104176

# %%
print("Nodes:", len(community_graphs[2].nodes))
print("Edges", len(community_graphs[2].edges))
commmunity_graphs_2_closeness = timed_centrality(community_graphs[2])
# Out:
# Nodes: 342184
# Edges 3759790
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-59fa7799bbcf> in <module>
#       1 print("Nodes:", len(community_graphs[2].nodes))
#       2 print("Edges", len(community_graphs[2].edges))
# ----> 3 commmunity_graphs_2_closeness = timed_centrality(community_graphs[2])
#
# <ipython-input-59-b3ce8660f0b1> in timed(*args)
#       2     def timed(*args):
#       3         start = time.time()
# ----> 4         ret = func(*args)
#       5         end = time.time()
#       6         print("Time taken", end - start)
#
# /usr/local/anaconda3/envs/voter-fraud/lib/python3.8/site-packages/networkx/algorithms/centrality/closeness.py in closeness_centrality(G, u, distance, wf_improved)
#     111     closeness_centrality = {}
#     112     for n in nodes:
# --> 113         sp = path_length(G, n)
#     114         totsp = sum(sp.values())
#     115         len_G = len(G)
#
# /usr/local/anaconda3/envs/voter-fraud/lib/python3.8/site-packages/networkx/algorithms/shortest_paths/unweighted.py in single_source_shortest_path_length(G, source, cutoff)
#      57         cutoff = float("inf")
#      58     nextlevel = {source: 1}
# ---> 59     return dict(_single_shortest_path_length(G.adj, nextlevel, cutoff))
#      60
#      61
#
# /usr/local/anaconda3/envs/voter-fraud/lib/python3.8/site-packages/networkx/algorithms/shortest_paths/unweighted.py in _single_shortest_path_length(adj, firstlevel, cutoff)
#      89             return
#      90         for v in found:
# ---> 91             nextlevel.update(adj[v])
#      92         level += 1
#      93     del seen
#
# KeyboardInterrupt:

# %%
node_closeness = nx.algorithms.centrality.closeness_centrality(community_graphs[4], 1014567)
node_closeness
# Out:
# 0.0002485021918669892

# %%
node_closeness = nx.algorithms.centrality.closeness_centrality(community_graphs[1], node_id_map["25073877"])
node_closeness
# Out:
# 0.0013523511882467215

# %%
import numpy as np
import scipy.sparse
import scipy.sparse.csgraph

# %%
def get_largest_subgraph(graph):
    undirected_graph = graph.to_undirected()
    connected_components = [graph.subgraph(c) for c in nx.connected_components(undirected_graph)]
    largest_component = max(connected_components, key=len)
    return graph.subgraph(largest_component.nodes)

# %%
largest_subgraph = get_largest_subgraph(cached_graph["graph"].to_undirected())

# %%
print("Nodes in largest subgraph:", len(largest_subgraph.nodes))
# Out:
# Nodes in largest subgraph: 1854896

# %%
def print_cluster_stats(df_users, cluster_type, N=5, top_users=10):
    community_node_map = cached_graph[cluster_type][1]
    for c in range(N): 
        cluster_users = df_users[df_users[cluster_type] == c]
        cluster_nodes = len(community_node_map[c])
        print("Cluster {} (user ids in cluster: {} ({:,.1f}%), identified users: {})".format(
            c, 
            cluster_nodes, 
            (cluster_nodes / len(cached_graph["graph"].nodes)) * 100,
            cluster_users.shape[0])
        )
        print("Top users")
        print(cluster_users[["handle", "followers_count"]][:top_users])
        print("Follower count:")
        print("- mean {:,.1f}".format(cluster_users["followers_count"].mean()))
        print("- min {:,}".format(cluster_users["followers_count"].min()))
        print("- max {:,}".format(cluster_users["followers_count"].max()))
        print("- median {:,.0f}".format(cluster_users["followers_count"].median()))
        print()

def cluster_users(df_users, node_id_map, node_community_map):
    clusters = []
    missing_in_graph = 0
    missing_assignment = 0
    for user_id, user in df_users.iterrows():
        if user_id in node_id_map:
            node_id = node_id_map[user_id]
            if node_id in node_community_map:
                cluster = node_community_map[node_id]
                clusters.append(cluster)
            else:
                missing_assignment += 1
                clusters.append(-1)    
        else:
            missing_in_graph += 1
            clusters.append(-1)
    print("{} missing assignment".format(missing_assignment))
    print("{} missing in graph".format(missing_in_graph))
    return clusters

# %%
df_all_users = pd.read_pickle(EXPORT_DIR + 'df_users.pickle')

# %%
# Cluster users
df_all_users["clustering_directed_unweighted"] = cluster_users(df_all_users, node_id_map, cached_graph["clustering_directed_weighted"][0])
df_all_users["clustering_directed_weighted"] = cluster_users(df_all_users, node_id_map, cached_graph["clustering_directed_unweighted"][0])
# Out:
# 2122 missing assignment
# 671282 missing in graph
# 2122 missing assignment
# 671282 missing in graph

# %%
df_all_users["clustering_undirected_unweighted"] = cluster_users(df_all_users, node_id_map, cached_graph["clustering_undirected_unweighted"][0])
# Out:
# 2122 missing assignment
# 671282 missing in graph

# %%
df_all_users_with_clustering = pd.read_pickle("./df_users_with_clustering.pickle")

# %%
def get_all_users_by_cluster(cluster_type):
    # All users
    all_users_by_cluster = df_all_users.sort_values([cluster_type, "followers_count"], ascending=False).reset_index().set_index(cluster_type)
    all_users_by_cluster["user"] = all_users_by_cluster["datastore_id"]
    return all_users_by_cluster

all_users_by_cluster = get_all_users_by_cluster("cluster_directed_unweighted")

# %%
# Top users
df_weekly_top_users = pd.read_pickle(EXPORT_DIR + 'df_weekly_top_users.pickle')
df_top_users = df_weekly_top_users.groupby(["user", "handle", "name", "followers_count", "verified"]).sum().reset_index().set_index("user")
df_top_users["cluster"] = cluster_users(df_top_users, node_id_map, node_community_map)
top_users_by_cluster = df_top_users.sort_values(["cluster", "followers_count"], ascending=[True, False]).reset_index().set_index("cluster")
# Out:
# 18 missing assignment
# 21 missing in graph

# %%
print_cluster_stats(df_all_users_with_clustering.sort_values("followers_count", ascending=False), "clustering_directed_weighted", 5, 25)
# Out:
# Cluster 0 (user ids in cluster: 860976 (45.6%), identified users: 253438)
# Top users
#                        handle  followers_count
# datastore_id
# 428333                 cnnbrk         59420316
# 759251                    CNN         50395181
# 807095                nytimes         47663855
# 5402612           BBCBreaking         46468749
# 1339835893     HillaryClinton         29737638
# 742143               BBCWorld         29485728
# 5988062          TheEconomist         25123658
# 1652541               Reuters         22518102
# 16303106        StephenAtHome         19138480
# 3108351                   WSJ         18173551
# 14293310                 TIME         17528521
# 2467791        washingtonpost         16493705
# 91478624               Forbes         16368043
# 28785486                  ABC         16013155
# 51241574                   AP         14507714
# 18948541       SethMacFarlane         13985869
# 37034483                 ndtv         13913844
# 95023423            UberFacts         13788821
# 1115874631       CGTNOfficial         13770512
# 216776631       BernieSanders         13238075
# 134758540        timesofindia         13206168
# 487118986              XHNews         12581202
# 30364057      SarahKSilverman         12531468
# 26053643          jimmykimmel         11877412
# 14075928             TheOnion         11592157
# Follower count:
# - mean 10,904.4
# - min 0
# - max 59,420,316
# - median 421
#
# Cluster 1 (user ids in cluster: 437783 (23.2%), identified users: 130530)
# Top users
#                              handle  followers_count
# datastore_id
# 25073877            realDonaldTrump         87364085
# 1367531                     FoxNews         20032865
# 240649814                  TimesNow          9878359
# 52544275                IvankaTrump          9753910
# 39344374             DonaldJTrumpJr          5908551
# 41634520                seanhannity          5352161
# 22703645              TuckerCarlson          4557133
# 2916305152                  Snowden          4413971
# 39349894                  EricTrump          4336219
# 15745368                 marcorubio          4222284
# 23022687                    tedcruz          4105340
# 50769180              IngrahamAngle          3881193
# 23970102                BillOReilly          3348643
# 17995040                 benshapiro          3310062
# 216881337                  RandPaul          2988889
# 878247600096509952     RealCandaceO          2713785
# 78523300             RealJamesWoods          2695993
# 988573326376427520        SecPompeo          2677360
# 38495835              marklevinshow          2592197
# 232901331                  dbongino          2582411
# 11134252                        GOP          2558770
# 110445334                megynkelly          2546899
# 44945327            Franklin_Graham          2421595
# 20713061               newtgingrich          2375678
# 29458079               JudgeJeanine          2332701
# Follower count:
# - mean 4,131.2
# - min 0
# - max 87,364,085
# - median 70
#
# Cluster 2 (user ids in cluster: 342184 (18.1%), identified users: 247484)
# Top users
#                        handle  followers_count
# datastore_id
# 16589206            wikileaks          5611146
# 18166778           Jim_Jordan          1955593
# 15513604        foxandfriends          1363214
# 31428361            F1abraham          1127886
# 6054912            TobyTurner           973688
# 37279768          behindwoods           959045
# 614884262        oliverpocher           757462
# 191795989         ewnreporter           695846
# 112243365         futureshift           654047
# 20897273             PAMsLOvE           645323
# 23181999            TJHuntley           562582
# 239098915         mattletiss7           534732
# 16703058             BraveLad           524397
# 90573676           jerrysaltz           522282
# 3168033757           Karma_Rx           514991
# 15933690               NBCDFW           474307
# 39384517               ICEgov           459294
# 19032473                9NEWS           451996
# 53757167        SwedishCanary           451565
# 259096053           L_A_Baker           444474
# 1014922465       RudawEnglish           408179
# 16740433      DeAnna4Congress           393461
# 15040988       geoff_deweaver           391409
# 578321883        GingerGander           378722
# 99943864      Daminous_Purity           374871
# Follower count:
# - mean 2,272.8
# - min 0
# - max 5,611,146
# - median 418
#
# Cluster 3 (user ids in cluster: 33587 (1.8%), identified users: 5834)
# Top users
#                              handle  followers_count
# datastore_id
# 362401254             katsuyatakasu           812969
# 954614844              _yavuzatalay           788890
# 145991905              hyakutanaoki           464017
# 32394429                 FIFI_Egypt           462683
# 24611873                   ikedanob           294179
# 57870730                smith796000           249781
# 1128981340848656384    KadotaRyusho           246805
# 109458204                 kohyu1952           193440
# 442782547                  BBCIndia           192656
# 92957264                hirosetakao           187512
# 937991325584109568       MeidocafeR           145544
# 835040085573689346    ganaha_masako           136654
# 67432456                    akiman7           132574
# 1026345980              aichikyu369           131704
# 4838815874              Shin_Kurose           124659
# 22434517                HillelNeuer           119360
# 822547465874378752   TrumpTrackerJP           113076
# 207082508                 Japangard           108811
# 23517712                      WTKR3           104359
# 152137205             onoderamasaru            83822
# 1086230647100792832    okabaeri9111            79574
# 147536278                Mishimadou            75631
# 2877651816              shoetsusato            71491
# 379382447            lovely_things1            71340
# 132545869                   mk00350            68076
# Follower count:
# - mean 2,424.1
# - min 0
# - max 812,969
# - median 350
#
# Cluster 4 (user ids in cluster: 23414 (1.2%), identified users: 4939)
# Top users
#                        handle  followers_count
# datastore_id
# 18949452                   FT          4276086
# 23719107      nelsonbocaranda          3276319
# 72627916          carlaangola          2682437
# 46919513          williecolon          2042111
# 104683173           Excelsior          1968920
# 186961616     ReinaldoProfeta          1597717
# 95134013        traffiCARACAS          1587536
# 65728343        carlosvecchio          1025577
# 42832810             eldiario           925349
# 221378668           ReporteYa           911107
# 121615397       ADRIANAAZZIAS           842414
# 220055314         GenPenaloza           675093
# 115604864      humbertotweets           617556
# 108632445          kiara_true           610491
# 99187264        RConfidencial           534435
# 81202321         maibortpetit           530969
# 26778965       estebangerbasi           489601
# 85427368            Juliococo           406734
# 166546290          MilvaGauto           392344
# 92376011         garciabanchs           348317
# 82664640         jcsosazpurua           342378
# 166275230          LaNacionPy           325251
# 150701482        laprensalara           301634
# 48841325             estarc62           300521
# 36414477          usembassyve           285921
# Follower count:
# - mean 10,201.3
# - min 0
# - max 4,276,086
# - median 864

# %%
df_all_users.to_pickle("./df_users_with_clustering.pickle")

# %%
df_recent_tweets = pd.read_pickle(EXPORT_DIR + 'df_recent_tweets.pickle')

# %%
df_recent_tweets["community"] = df_recent_tweets.apply(lambda x: )

# %%
cached_graph["graph"].edges(node_id_map["90573676"])
# Out:
# InEdgeDataView([(185, 423932), (3019, 423932), (4205, 423932), (211, 423932), (78, 423932), (6600, 423932), (271, 423932)])

# %%
node_id_map["90573676"]
# Out:
# 423932

# %%
def print_node_edges(user_id):
    out_edges = defaultdict(lambda: 0)
    in_edges = defaultdict(lambda: 0)
    print("Out edges")
    for (source, target) in cached_graph["graph"].out_edges(node_id_map[user_id]):
        cluster = node_community_map[target]
        if (cluster < 5):
            #print(cached_graph["graph"].nodes[target])
            out_edges[cluster] += 1
        else:
            out_edges["fringe"] += 1
    print(dict(out_edges))
    print("In edges")
    for (source, target) in cached_graph["graph"].in_edges(node_id_map[user_id]):
        cluster = node_community_map[source]
        if (cluster < 5):
            #print(cached_graph["graph"].nodes[target])
            in_edges[cluster] += 1
        else:
            in_edges["fringe"] += 1
    print(dict(in_edges))

# %%
# Jerry Saltz (Left-leaning)
print_node_edges("90573676")
# Out:
# Out edges
# {0: 3, 2: 4}
# In edges
# {0: 6, 1: 1}

# %%
# tveitdal (Left-leaning)
print_node_edges("75742264")
# Out:
# Out edges
# {0: 3, 2: 4, 'fringe': 1}
# In edges
# {2: 1}

# %%
# Press Sec (Right-leaning)
print_node_edges("818927131883356161")
# Out:
# Out edges
# {2: 2, 470: 1}
# In edges
# {}

# %%
# Jim Jordan (Cluster 2, right-leaning)
print_node_edges("18166778")
# Out:
# Out edges
# {2: 1}
# In edges
# {}

# %%
# Toby Turner (Cluster 2, right-leaning)
print_node_edges("6054912")
# Out:
# Out edges
# {2: 2}
# In edges
# {}

# %%
# Press Sec (Cluster 2, right-leaning)
print_node_edges("")

# %%
def sample_prominent_nodes(graph):
    high_follower_nodes = [x for x,y in graph.nodes(data=True) if 'followers' in y and y['followers']>25000]
    high_follower_graph = graph.subgraph(high_follower_nodes)

    prominent_nodes = [node for (node, degrees) in graph_with_communities.degree() if degrees > 100]

    return high_follower_graph.subgraph(prominent_nodes)

# %%
prominent_graph = sample_prominent_nodes(graph_with_communities)

# %%
print(len(prominent_graph.nodes))
print(len(prominent_graph.edges))
# Out:
# 4324
# 156723

# %%
print(len(prominent_graph.nodes))
print(len(prominent_graph.edges))
# Out:
# 8630
# 186116

# %%
import random

def sample_connected_graph(graph, k = 100000):
    sampled_nodes = random.sample(graph_with_communities.nodes, k)
    sampled_graph = graph_with_communities.subgraph(sampled_nodes + list(prominent_graph.nodes())))

    connected_nodes_sample = get_largest_subgraph(sampled_graph.to_undirected())

    return graph_with_communities.subgraph(connected_nodes_sample)

# %%
sampled_graph = sample_connected_graph(graph_with_communities, 50000)
print(len(sampled_graph.nodes))
print(len(sampled_graph.edges))
# Out:
# 44474
# 456372

# %%
sampled_graph = sample_connected_graph(graph_with_communities, 150000)
print(len(sampled_graph.nodes))
print(len(sampled_graph.edges))
# Out:
# 58854
# 980496

# %%
sampled_graph.nodes[node_id_map["25073877"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d984eb6df5a9> in <module>
# ----> 1 sampled_graph.nodes[node_id_map["729676086632656900"]]
#
# NameError: name 'sampled_graph' is not defined

# %%
filename = "../data/graphs/08-jan-sampled-graph-with-communities.gexf"
nx.write_gexf(sampled_graph, filename)
print("Exported to {}".format(filename))
# Out:
# Exported to ../data/graphs/08-jan-sampled-graph-with-communities-smaller.gexf
